# %%
from warnings import filterwarnings
filterwarnings('ignore')
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.cluster import KMeans

# %% [markdown]
# # K-Means

# %%
df = pd.read_csv("USArrests.csv").copy()
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
# Unnamed kolonunu değişken olarak gösteriyor. Gözlem yapmak istiyoruz
# Bu yüzden 0.kolunu index'e atadık.

# %%
df.index = df.iloc[:,0]

# %%
df.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='Unnamed: 0')

# %%
df.head()
# Out:
#             Unnamed: 0  Murder  Assault  UrbanPop  Rape
# Unnamed: 0
# Alabama        Alabama    13.2      236        58  21.2
# Alaska          Alaska    10.0      263        48  44.5
# Arizona        Arizona     8.1      294        80  31.0
# Arkansas      Arkansas     8.8      190        50  19.5
# California  California     9.0      276        91  40.6

# %%
df = df.iloc[:,1:5] # 0.kolonu yoketmemiz lazım

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Unnamed: 0
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
df.index.name = None

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
df.isnull().sum()
# Out:
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 2.0+ KB

# %%
df.describe().T
# Out:
#           count     mean        std   min      25%     50%      75%    max
# Murder     50.0    7.788   4.355510   0.8    4.075    7.25   11.250   17.4
# Assault    50.0  170.760  83.337661  45.0  109.000  159.00  249.000  337.0
# UrbanPop   50.0   65.540  14.474763  32.0   54.500   66.00   77.750   91.0
# Rape       50.0   21.232   9.366385   7.3   15.075   20.10   26.175   46.0

# %%
# Burada Murder ağır bir suç olduğu için ağırlığını arttırmak ya da yeni bir değişken eklemek önemli olabilir.
# Ortlaması 7'den fazla olan eyaletlere daha fazla ağırlık verilebilir.

# %%
df.hist(figsize = (10,10));
# Dağılımlara bakıp ilkel bir segmentasyon yapabiliriz.
# Mesela murder özelinde 2 tepeli yapıyı hangi eyaletler oluşturuyor?
# Detayını incelemek önemli.

# %% [markdown]
# ## K-MEANS Model ve Görselleştirme

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 4)
kmeans
# n_clusters argümanını başlasın diye 4 verdik. Herhangi bir başka numara da verebiliriz.
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
k_fit = kmeans.fit(df)

# %%
k_fit.n_clusters
# Out:
# 4

# %%
k_fit.cluster_centers_
# Out:
# array([[  2.95      ,  62.7       ,  53.9       ,  11.51      ],
#        [ 11.8125    , 272.5625    ,  68.3125    ,  28.375     ],
#        [  8.21428571, 173.28571429,  70.64285714,  22.84285714],
#        [  5.59      , 112.4       ,  65.6       ,  17.27      ]])

# %%
k_fit.labels_  # Hangi gözlem hangi değerleri almış.
# Out:
# array([1, 1, 1, 2, 1, 2, 3, 1, 1, 2, 0, 3, 1, 3, 0, 3, 3, 1, 0, 1, 2, 1,
#        0, 1, 2, 3, 3, 1, 0, 2, 1, 1, 1, 0, 3, 2, 2, 3, 2, 1, 0, 2, 2, 3,
#        0, 2, 2, 0, 0, 2], dtype=int32)

# %%
## Görsellestirme

# %%
kmeans = KMeans(n_clusters = 2)
k_fit = kmeans.fit(df)

# %%
kumeler = k_fit.labels_

# %%
plt.scatter(df.iloc[:,0], df.iloc[:,1], c = kumeler, s = 50, cmap = "viridis")

merkezler = k_fit.cluster_centers_

plt.scatter(merkezler[:,0], merkezler[:,1], c = "black", s = 200, alpha = 0.5);

# %%
# İki boyutlu şekilde görselleştirmiş olduk. PCA uyguladıktan sonra da görselleştirebiliriz.

# %%
#pip install --upgrade matplotlib
#import mpl_toolkits

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
kmeans = KMeans(n_clusters = 3)
k_fit = kmeans.fit(df)
kumeler = k_fit.labels_
merkezler = kmeans.cluster_centers_

# %%
plt.rcParams['figure.figsize'] = (16, 9)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2]);

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2], c=kumeler)
ax.scatter(merkezler[:, 0], merkezler[:, 1], merkezler[:, 2], 
           marker='*', 
           c='#050505', 
           s=1000);

# %%
#kumeler ve gözlem birimleri

# %%
kmeans = KMeans(n_clusters = 3)
k_fit = kmeans.fit(df)
kumeler = k_fit.labels_

# %%
pd.DataFrame({"Eyaletler" : df.index, "Kumeler": kumeler})[0:10]
# Out:
#      Eyaletler  Kumeler
# 0      Alabama        1
# 1       Alaska        1
# 2      Arizona        1
# 3     Arkansas        0
# 4   California        1
# 5     Colorado        0
# 6  Connecticut        2
# 7     Delaware        1
# 8      Florida        1
# 9      Georgia        0

# %%
df["kume_no"] = kumeler

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape  kume_no
# Alabama       13.2      236        58  21.2        1
# Alaska        10.0      263        48  44.5        1
# Arizona        8.1      294        80  31.0        1
# Arkansas       8.8      190        50  19.5        0
# California     9.0      276        91  40.6        1

# %%
df["kume_no"] = df["kume_no"] + 1

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape  kume_no
# Alabama       13.2      236        58  21.2        2
# Alaska        10.0      263        48  44.5        2
# Arizona        8.1      294        80  31.0        2
# Arkansas       8.8      190        50  19.5        1
# California     9.0      276        91  40.6        2

# %% [markdown]
# # Optimum Kume Sayısının Belirlenmesi

# %%
# !pip install yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer
kmeans = KMeans()
visualizer = KElbowVisualizer(kmeans, k=(2,20))
visualizer.fit(df) 
visualizer.poof()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-a8c08120eafe> in <module>
# ----> 1 from yellowbrick.cluster import KElbowVisualizer
#       2 kmeans = KMeans()
#       3 visualizer = KElbowVisualizer(kmeans, k=(2,20))
#       4 visualizer.fit(df)
#       5 visualizer.poof()
#
# ~/anaconda3/lib/python3.7/site-packages/yellowbrick/cluster/__init__.py in <module>
#      23 from .elbow import *
#      24 from .silhouette import *
# ---> 25 from .icdm import *
#
# ~/anaconda3/lib/python3.7/site-packages/yellowbrick/cluster/icdm.py in <module>
#      32 try:
#      33     # Only available in Matplotlib >= 2.0.2
# ---> 34     from mpl_toolkits.axes_grid1 import inset_locator
#      35 except ImportError:
#      36     inset_locator = None
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/axes_grid1/inset_locator.py in <module>
#     135
#     136
# ...

# %%
kmeans = KMeans(n_clusters = 4)
k_fit = kmeans.fit(df)
kumeler = k_fit.labels_

# %%
pd.DataFrame({"Eyaletler" : df.index, "Kumeler": kumeler})[0:10]
# Out:
#      Eyaletler  Kumeler
# 0      Alabama        1
# 1       Alaska        1
# 2      Arizona        1
# 3     Arkansas        3
# 4   California        1
# 5     Colorado        3
# 6  Connecticut        2
# 7     Delaware        1
# 8      Florida        1
# 9      Georgia        3

# %% [markdown]
# # Hiyerarşik Kümeleme

# %%
# Amaç gözlemleri birbirlerine olan benzerliklerine göre alt kümelere ayırmaktır.
# Birleştirici ve bölümleyici teknikler var.
# Bağımlı değişken olmadığından değişkenler üzerinden kümeleme yapılabilir.

# %%
df = pd.read_csv("USArrests.csv").copy()
df.index = df.iloc[:,0]
df = df.iloc[:,1:5]
# df.index.name = None
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
from scipy.cluster.hierarchy import linkage
hc_complete = linkage(df, "complete")
hc_average = linkage(df, "average")
hc_single = linkage(df, "single")

# %%
dir(hc_complete)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hiyerarşik Kümeleme - Dendogram')
plt.xlabel('Indexler')
plt.ylabel('Uzaklık')
dendrogram(
    hc_complete,
    leaf_font_size=10
);

# %%
# Belirli sayıda kümeye (p =4 argümanı) ayırmak istersen
# Toplamda 50 gözlem olan kümeler ayrı ayrı gösteriliyor aşağıda.
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hiyerarşik Kümeleme - Dendogram')
plt.xlabel('Indexler')
plt.ylabel('Uzaklık')
dendrogram(
    hc_complete,
    truncate_mode = "lastp",
    p = 4,
    show_contracted = True
);

# %% [markdown]
# ## Optimum Küme Sayısı

# %%
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hiyerarşik Kümeleme - Dendogram')
plt.xlabel('Indexler')
plt.ylabel('Uzaklık')
den = dendrogram(
    hc_complete,
    leaf_font_size=10
);

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters = 4, 
                                  affinity = "euclidean", 
                                  linkage = "ward")

cluster.fit_predict(df)
# Out:
# array([0, 0, 0, 2, 0, 2, 3, 0, 0, 2, 1, 3, 0, 3, 1, 3, 3, 0, 1, 0, 2, 0,
#        1, 0, 2, 3, 3, 0, 1, 2, 0, 0, 0, 1, 3, 2, 2, 3, 2, 0, 1, 2, 2, 3,
#        1, 2, 2, 1, 1, 2])

# %%
pd.DataFrame({"Eyaletler" : df.index, "Kumeler": cluster.fit_predict(df)})[0:10]
# Out:
#      Eyaletler  Kumeler
# 0      Alabama        0
# 1       Alaska        0
# 2      Arizona        0
# 3     Arkansas        2
# 4   California        0
# 5     Colorado        2
# 6  Connecticut        3
# 7     Delaware        0
# 8      Florida        0
# 9      Georgia        2

# %%
df["kume_no"] = cluster.fit_predict(df)

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape  kume_no
# Alabama       13.2      236        58  21.2        0
# Alaska        10.0      263        48  44.5        0
# Arizona        8.1      294        80  31.0        0
# Arkansas       8.8      190        50  19.5        2
# California     9.0      276        91  40.6        0

# %% [markdown]
# # PCA

# %%
# Temel fikir, çok değişkenli verinin ana özelliklerini daha az sayıda değişken/bileşen ile temsil etmektir.
# Nedensellik ilişkisi önemli değilse kullanabilirsin yoksa PLS KULLAN.

# %%
df = pd.read_csv("USArrests.csv").copy()
df.index = df.iloc[:,0]
df = df.iloc[:,1:5]
#df.index.name = None
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# PCA İçin öncelikle değişkenleri standartlaştırmamız gerekmektedir.

# %%
from sklearn.preprocessing import StandardScaler

df = StandardScaler().fit_transform(df)
df[0:5,0:5] # Gözlemleri incele.
# Out:
# array([[ 1.25517927,  0.79078716, -0.52619514, -0.00345116],
#        [ 0.51301858,  1.11805959, -1.22406668,  2.50942392],
#        [ 0.07236067,  1.49381682,  1.00912225,  1.05346626],
#        [ 0.23470832,  0.23321191, -1.08449238, -0.18679398],
#        [ 0.28109336,  1.2756352 ,  1.77678094,  2.08881393]])

# %%
# PCA uyguluyoruz.
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca_fit = pca.fit_transform(df)

# %%
bilesen_df = pd.DataFrame(data = pca_fit, 
                          columns = ["birinci_bilesen","ikinci_bilesen",])

# %%
bilesen_df.head()
# Out:
#    birinci_bilesen  ikinci_bilesen
# 0         0.985566        1.133392
# 1         1.950138        1.073213
# 2         1.763164       -0.745957
# 3        -0.141420        1.119797
# 4         2.523980       -1.542934

# %%
# Gerçek veri setinin ne kadarını taşıyor.temsiliyet oranı
pca.explained_variance_ratio_
# Out:
# array([0.62006039, 0.24744129])

# %%
# Kaç değişkene indirgeyeceksin?
pca = PCA().fit(df)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
